# %%
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
from torch import optim
from tqdm import tqdm
import sys
import math

# %% [markdown]
# # TransformerALI: Adaptive Learning wint Integration Transformer

# %%
def sqlData(var, n, e):
    data = []
    str, stp = np.random.randint(0, 20, 2)
    x = np.linspace(str, stp, n)
    if var>2:
        data.append(x)
        data.append(np.random.normal(0, np.random.rand(), n))
        var -= 2
    x = np.zeros_like(x)
    for i in range(var):
        stra, stpa = np.random.randint(-n//2, n//2, 2)
        x += np.sin(np.linspace(str+str, stp+stpa, n))*stra * (i + 1) + 2
        data.append(x.copy())
    return data

# %%
def dataset(n, batchsize, func, func_args):
    out = np.array([np.array(func(*func_args)) for _ in range(batchsize)])
    rnd = np.random.randint(0, out.shape[2]//4, n//batchsize)
    sql = np.random.randint(out.shape[2]//4, out.shape[2]*3//4, n//batchsize)
    for i in range(n//batchsize):
        src = out[: , :, rnd[i]:rnd[i]+sql[i]]
        tgt = out[:, :, rnd[i]+sql[i]+1] # .reshape(-1, 4, 1)
        yield src, tgt

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, var:int, dropout: float = 0.0, max_len: int = 5000):
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        pe = torch.zeros(max_len, 1, var)
        for i in range(var):
            pe[:, 0, i] = torch.linspace(0, 1, max_len)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)


# class transformerNNDuel(nn.Module):
#     def __init__(self, var, nEncoder, nDecoder, d_model):
#         super().__init__()
#         encoderLayers = []
#         nEncoderS = np.linspace(var, d_model, nEncoder+1, dtype=np.int32)
#         for i in range(len(nEncoderS)-1):
#             encoderLayers.append(nn.Linear(nEncoderS[i], nEncoderS[i+1]))
#             encoderLayers.append(nn.ReLU(inplace=True))
            
#         self.encoder = nn.Sequential(*nn.ModuleList(encoderLayers))

#         self.pos_encoder = PositionalEncoding(d_model)
#         enc = nn.TransformerEncoderLayer(d_model=d_model, nhead=8, dropout=0)
#         self.transformerEncoder = nn.TransformerEncoder(enc, num_layers=6)    
    
#         decoderLayers = []
#         nDecoderS = np.linspace(d_model, var, nDecoder+1, dtype=np.int32)
#         for i in range(len(nDecoderS)-1):
#             decoderLayers.append(nn.Linear(nDecoderS[i], nDecoderS[i+1]))
#             if i == len(nDecoderS)-2:
#                 break
#             decoderLayers.append(nn.ReLU(inplace=True))
            
#         self.adv = nn.Sequential(*nn.ModuleList(decoderLayers))

#         decoderLayers = []
#         nDecoderS = np.linspace(d_model, 1, nDecoder+1, dtype=np.int32)
#         for i in range(len(nDecoderS)-1):
#             decoderLayers.append(nn.Linear(nDecoderS[i], nDecoderS[i+1]))
#             if i == len(nDecoderS)-2:
#                 break
#             decoderLayers.append(nn.ReLU(inplace=True))
            
#         self.state = nn.Sequential(*nn.ModuleList(decoderLayers))

#         self.s = None
#         self.a = None
        
#     @staticmethod
#     def mask(sz):
#         mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
#         mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
#         return mask
    
#     def forward(self, x):
#         x = self.encoder(x)
#         x = self.pos_encoder(x)
#         x = self.transformerEncoder(x, mask=self.mask(len(x)))
#         self.s = self.state(x) # 1
#         self.a = self.adv(x) # seq
#         x = self.s + (self.a - self.a.mean(2).unsqueeze(2))
#         return x


# class transformerNN(nn.Module):
#     def __init__(self, var, nEncoder, nDecoder, d_model):
#         super().__init__()
#         encoderLayers = []
#         nEncoderS = np.linspace(var, d_model, nEncoder+1, dtype=np.int32)
#         for i in range(len(nEncoderS)-1):
#             encoderLayers.append(nn.Linear(nEncoderS[i], nEncoderS[i+1]))
#             encoderLayers.append(nn.ReLU(inplace=True))
            
#         self.encoder = nn.Sequential(*nn.ModuleList(encoderLayers))

#         self.pos_encoder = PositionalEncoding(d_model)
#         enc = nn.TransformerEncoderLayer(d_model=d_model, nhead=8, dropout=0)
#         self.transformerEncoder = nn.TransformerEncoder(enc, num_layers=6)    
    
#         decoderLayers = []
#         nDecoderS = np.linspace(d_model, var, nDecoder+1, dtype=np.int32)
#         for i in range(len(nDecoderS)-1):
#             decoderLayers.append(nn.Linear(nDecoderS[i], nDecoderS[i+1]))
#             if i == len(nDecoderS)-2:
#                 break
#             decoderLayers.append(nn.ReLU(inplace=True))
            
#         self.decoder = nn.Sequential(*nn.ModuleList(decoderLayers))

        
#     @staticmethod
#     def mask(sz):
#         mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
#         mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
#         return mask
    
#     def forward(self, x):
#         x = self.encoder(x)
#         x = self.pos_encoder(x)
#         x = self.transformerEncoder(x, mask=self.mask(len(x)))
#         x = self.decoder(x)
#         return x


# class vanillaNN(nn.Module):
#     def __init__(self, var, nEncoder, nDecoder, d_model):
#         super().__init__()
#         encoderLayers = []
#         nEncoderS = np.linspace(var, d_model, nEncoder+1, dtype=np.int32)
#         for i in range(len(nEncoder)-1):
#             encoderLayers.append(nn.Linear(nEncoderS[i], nEncoderS[i+1]))
#             encoderLayers.append(nn.ReLU(inplace=True))
            
#         self.encoder = nn.Sequential(*nn.ModuleList(encoderLayers))
    
#         decoderLayers = []
#         nEncoderS = np.linspace(d_model, var, nDecoder+1, dtype=np.int32)
#         for i in range(len(nDecoder)-1):
#             decoderLayers.append(nn.Linear(nEncoderS[i], nEncoderS[i+1]))
#             if i == len(nEncoderS)-2:
#                 break
#             decoderLayers.append(nn.ReLU(inplace=True))
            
#         self.decoder = nn.Sequential(*nn.ModuleList(decoderLayers))

    
#     def forward(self, x):
#         x = self.encoder(x)
#         x = self.decoder(x)
#         return x

# %%
# class transformerFantasy(nn.Module):
#     def __init__(self, seq, var, nEncoder, nDecoder, d_model):
#         super().__init__()

#         self.pos = PositionalEncoding(var, max_len=seq)
        
#         encoderLayers = []
#         nEnc = np.linspace(seq, d_model, nEncoder+1, dtype=np.int32)
#         for i in range(len(nEnc)-1):
#             encoderLayers.append(nn.Linear(nEnc[i], nEnc[i+1]))
#             encoderLayers.append(nn.ReLU(inplace=True))
#         self.seqEncoder = nn.Sequential(*nn.ModuleList(encoderLayers))

#         encoderLayers = []
#         nEnc = np.linspace(var, d_model, nEncoder+1, dtype=np.int32)
#         for i in range(len(nEnc)-1):
#             encoderLayers.append(nn.Linear(nEnc[i], nEnc[i+1]))
#             encoderLayers.append(nn.ReLU(inplace=True))
#         self.varEncoder = nn.Sequential(*nn.ModuleList(encoderLayers))
        
#         self.transformer = torch.nn.Transformer(d_model=d_model, nhead=8, num_encoder_layers=6, num_decoder_layers=6)
    
#         decoderLayers = []
#         nDec = np.linspace(d_model, var, nDecoder+1, dtype=np.int32)
#         for i in range(len(nDec)-1):
#             decoderLayers.append(nn.Linear(nDec[i], nDec[i+1]))
#             if i == len(nDec)-2:
#                 break
#             decoderLayers.append(nn.ReLU(inplace=True))
#         self.decoder = nn.Sequential(*nn.ModuleList(decoderLayers))

#         self.msk = self.mask(seq)
    
#     @staticmethod
#     def mask(sz):
#         mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
#         mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
#         return mask.to("cuda")
    
#     def forward(self, x):
#         seq = self.seqEncoder(x.transpose(0, 2))
#         var = self.varEncoder(self.pos(x))
#         x = self.transformer(seq, var, tgt_mask = self.msk) #
#         x = self.decoder(x)
#         return x

# %%
# class transformerFantasy2(nn.Module):
#     def __init__(self, var, nEncoder, nDecoder, d_model):
#         super().__init__()

#         self.pos = PositionalEncoding(var, max_len=var*1000)
        
#         encoderLayers = []
#         nEnc = np.linspace(var, d_model, nEncoder+1, dtype=np.int32)
#         for i in range(len(nEnc)-1):
#             encoderLayers.append(nn.Linear(nEnc[i], nEnc[i+1]))
#             encoderLayers.append(nn.ReLU(inplace=True))
#         self.encoder = nn.Sequential(*nn.ModuleList(encoderLayers))
        
#         self.transformer = torch.nn.Transformer(d_model=var, nhead=var, num_encoder_layers=var*3, num_decoder_layers=var*3)
    
#         decoderLayers = []
#         nDec = np.linspace(d_model, var, nDecoder+1, dtype=np.int32)
#         for i in range(len(nDec)-1):
#             decoderLayers.append(nn.Linear(nDec[i], nDec[i+1]))
#             if i == len(nDec)-2:
#                 break
#             decoderLayers.append(nn.ReLU(inplace=True))
#         self.decoder = nn.Sequential(*nn.ModuleList(decoderLayers))
    
#     @staticmethod
#     def mask(sz):
#         mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
#         mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
#         return mask
    
#     def forward(self, x):
#         var = self.pos(x)
#         seq = x.transpose(0, 2)
        
#         print(var.shape, seq.shape)
#         x = self.transformer(var, seq, src_mask = self.mask(len(var))) #, tgt_mask = self.msk
#         x = self.decoder(x)        
#         return x

# %%
class transformerALI(nn.Module):
    def __init__(self, var, nEncoder, nDecoder, d_model):
        super().__init__()

        self.pos = PositionalEncoding(d_model, max_len=1000)
        
        encoderLayers = []
        nEnc = np.linspace(var, d_model, nEncoder+1, dtype=np.int32)
        for i in range(len(nEnc)-1):
            encoderLayers.append(nn.Linear(nEnc[i], nEnc[i+1]))
            encoderLayers.append(nn.ReLU(inplace=True))
        self.encoder = nn.Sequential(*nn.ModuleList(encoderLayers))
        
        enc = nn.TransformerEncoderLayer(d_model=d_model, nhead=8, dropout=0)
        self.transformerEncoder = nn.TransformerEncoder(enc, num_layers=6)    
    
        decoderLayers = []
        nDec = np.linspace(d_model, var, nDecoder+1, dtype=np.int32)
        for i in range(len(nDec)-1):
            decoderLayers.append(nn.Linear(nDec[i], nDec[i+1]))
            if i == len(nDec)-2:
                break
            decoderLayers.append(nn.ReLU(inplace=True))
        self.decoder = nn.Sequential(*nn.ModuleList(decoderLayers))
        self.mem = None
    
    @staticmethod
    def mask(sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.pos(x)
        x = self.transformerEncoder(x, self.mask(len(x)))
        x = self.decoder(x.mean(0)) # best score before decode doing average
        return x


def updateWeightSeq(model, seq):
    for param in model.parameters():
        if param.requires_grad:
            param.grad *= seq

# %%
# var = 4
# nEncoder = 4
# nDecoder = 4
# d_model = 512
# net = transformerHarbici(var, nEncoder, nDecoder, d_model)
# seq = random.randint(10, 20)
# net(torch.rand(seq, 32, var)).shape

# %%
# class CorrelationLoss(nn.Module):
#     def __init__(self):
#         super(CorrelationLoss, self).__init__()

#     def forward(self, x, y):
#         # Calculate the mean-centered versions of x and y
#         x_mean = x - torch.mean(x, dim=0, keepdim=True)
#         y_mean = y - torch.mean(y, dim=0, keepdim=True)

#         # Calculate the correlation
#         correlation = torch.sum(x_mean * y_mean) / (torch.sqrt(torch.sum(x_mean ** 2)) * torch.sqrt(torch.sum(y_mean ** 2)))

#         # Minimize the negative correlation to encourage positive correlation
#         loss = -correlation

#         return loss

# %%
epoch = 600
var = 4
seqlen = 40
dmodel = 256
lr = 5e-5
seq = 12
enc = 4
dec = 4
batchSize = 96
nEncoder = 3
nDecoder = 2

# net = transformerFantasy(seq, var, enc, dec, dmodel).to("cuda")
net = transformerALI(var, nEncoder, nDecoder, dmodel).to("cuda")
criterion = nn.MSELoss()
# criterion2 = CorrelationLoss()
optimizer = optim.Adam(net.parameters(), lr=lr)
hist = []

minLoss = float('inf')
for i in range(epoch):
    net.train()
    for j, (src, tgt) in enumerate(dataset(batchSize*8, batchSize, sqlData, (var, seqlen, 0.2))):
        src = torch.from_numpy(src).to(torch.float32).permute(2, 0, 1).to("cuda")
        tgt = torch.from_numpy(tgt).to(torch.float32).to("cuda")
        
        optimizer.zero_grad()

        outputs = net(src)
        loss = criterion(outputs, tgt) # *0.9 + criterion2(src, outputs)*0.1
        loss.backward()
        updateWeightSeq(net, len(src))
        optimizer.step()
        
    net.eval()
    runningLoss = 0
    for k, (src, tgt) in enumerate(dataset(batchSize*2, batchSize, sqlData, (var, seqlen, 0.2))):
        src = torch.from_numpy(src).to(torch.float32).permute(2, 0, 1).to("cuda")
        tgt = torch.from_numpy(tgt).to(torch.float32).to("cuda")
        
        with torch.no_grad():
             outputs = net(src)

        loss = criterion(outputs, tgt)

        runningLoss += loss.item()

    runningLoss = runningLoss/(k+1)
    
    if minLoss>runningLoss:
        minLoss = runningLoss
        bestWeights = net.state_dict().copy()
        
    hist.append(runningLoss)
    
    print(f'Current loss: {hist[-1]} Epoch: {i+1} ', end="\r")

# net._load_param = bestWeights.copy()
# Out:
# Current loss: 27.80203628540039 Epoch: 288

# %%
# net = transformerALI(var, nEncoder, nDecoder, dmodel).to("cuda")
# net._load_param = bestWeights.copy()

# %%
net._load_param
# Out:
# OrderedDict([('pos.pe',
#               tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#                       [[0.0010, 0.0010, 0.0010,  ..., 0.0010, 0.0010, 0.0010]],
#
#                       [[0.0020, 0.0020, 0.0020,  ..., 0.0020, 0.0020, 0.0020]],
#
#                       ...,
#
#                       [[0.9980, 0.9980, 0.9980,  ..., 0.9980, 0.9980, 0.9980]],
#
#                       [[0.9990, 0.9990, 0.9990,  ..., 0.9990, 0.9990, 0.9990]],
#
#                       [[1.0000, 1.0000, 1.0000,  ..., 1.0000, 1.0000, 1.0000]]],
#                      device='cuda:0')),
#              ('encoder.0.weight',
#               tensor([[ 0.1455,  0.2399, -0.3370,  0.4652],
#                       [ 0.2459,  0.0879, -0.4662, -0.2638],
#                       [ 0.0585, -0.2156,  0.2163,  0.2060],
#                       [-0.4116,  0.2756, -0.3343, -0.4474],
#                       [ 0.2429, -0.3574,  0.2521,  0.3904],
#                       [ 0.3715, -0.4052, -0.0506,  0.4380],
#                       [ 0.2119,  0.2340, -0.0194, -0.4518],
#                       [-0.0854, -0.2625, -0.1786, -0.1278],
#                       [ 0.1838,  0.4475,  0.2185,  0.3505],
#                       [-0.1856, -0.4007,  0.1398,  0.3321],
#                       [ 0.2954, -0.4579,  0.2518,  0.1417],
#                       [-0.3784,  0.2804, -0.1638, -0.3585],
#                       [ 0.2277, -0.4289, -0.3889,  0.1034],
#                       [ 0.1644,  0.0113, -0.1073, -0.0334],
#                       [ 0.3501,  0.0706,  0.2546,  0.4758],
#                       [ 0.2466,  0.4912, -0.0652, -0.1736],
#                       [ 0.2148, -0.4890,  0.3937, -0.2063],
#                       [-0.4978, -0.0403, -0.1680, -0.0963],
#                       [ 0.0296,  0.2065,  0.2085, -0.2392],
#                       [-0.3458, -0.3552, -0.0615,  0.1098],
#                       [-0.4199,  0.3698, -0.2963, -0.3011],
#                       [ 0.1684, -0.3208, -0.1776,  0.0129],
#                       [-0.4733, -0.3205,  0.0973,  0.0153],
#                       [-0.0141, -0.0265,  0.4920, -0.3532],
#                       [ 0.2548,  0.0190,  0.0456,  0.4239],
#                       [ 0.3687,  0.0491,  0.1953, -0.2790],
#                       [ 0.4729, -0.0985,  0.0474, -0.4007],
#                       [ 0.0111,  0.2546, -0.0368, -0.0161],
#                       [-0.3909,  0.1894, -0.4647, -0.1914],
#                       [-0.3583, -0.0005,  0.3169, -0.1648],
#                       [-0.4291, -0.2441, -0.2790, -0.0673],
#                       [-0.0925, -0.4314, -0.1706, -0.3646],
#                       [ 0.4095, -0.1226,  0.2313, -0.1590],
#                       [ 0.1319, -0.2410,  0.2012, -0.2311],
#                       [ 0.4518,  0.0789, -0.1058, -0.1597],
#                       [-0.5002, -0.2933,  0.1943, -0.3589],
#                       [ 0.1402, -0.4289, -0.3896, -0.3979],
#                       [-0.1654,  0.0969,  0.0685,  0.4075],
#                       [-0.1801, -0.0404, -0.3170,  0.1352],
#                       [ 0.3876,  0.4515,  0.3710, -0.1202],
#                       [ 0.4416, -0.1926,  0.3236, -0.0441],
#                       [-0.3538,  0.2405, -0.3615,  0.1985],
#                       [-0.2875,  0.2118, -0.4300,  0.1940],
#                       [-0.0720,  0.0748, -0.0510,  0.1225],
#                       [ 0.0171,  0.2451,  0.2721, -0.0726],
#                       [-0.4666,  0.1154,  0.0343, -0.1438],
#                       [-0.1412, -0.1755, -0.3770, -0.0355],
#                       [-0.3735,  0.2777,  0.2785, -0.0524],
#                       [ 0.1861, -0.1020,  0.0937,  0.3486],
#                       [-0.1598, -0.4286,  0.3572, -0.2880],
#                       [ 0.3225,  0.1432,  0.3308,  0.1858],
#                       [ 0.3629,  0.4628, -0.0163, -0.2614],
#                       [ 0.0271,  0.4236, -0.2689, -0.0567],
#                       [-0.0978, -0.4291,  0.2600, -0.4485],
#                       [-0.2284,  0.3816,  0.0008,  0.3136],
#                       [ 0.4131,  0.3299,  0.2377,  0.0339],
#                       [-0.0193,  0.2480, -0.2584, -0.0670],
#                       [ 0.1734, -0.2657, -0.2360, -0.2776],
#                       [ 0.0755, -0.1946, -0.3673,  0.2608],
#                       [-0.2270, -0.2249,  0.1712, -0.3227],
#                       [-0.3795,  0.0184, -0.3150,  0.1399],
#                       [-0.0213,  0.4575,  0.4002,  0.2225],
#                       [ 0.1065,  0.3608,  0.1579,  0.0311],
#                       [-0.1003,  0.4765,  0.0129, -0.1339],
#                       [-0.4831, -0.4086,  0.1020, -0.0504],
#                       [-0.2389,  0.2726,  0.4730, -0.4859],
#                       [ 0.1232,  0.2437,  0.1257,  0.1747],
#                       [ 0.2281, -0.2062,  0.3508,  0.1672],
#                       [-0.0955, -0.3100,  0.4710, -0.1967],
#                       [-0.4568, -0.1187,  0.1181, -0.4016],
#                       [ 0.0068,  0.1166,  0.3013,  0.0792],
#                       [ 0.2581,  0.4132,  0.0433, -0.0565],
#                       [-0.0384,  0.4265, -0.0044,  0.0094],
#                       [ 0.2236,  0.4421, -0.2143,  0.3632],
#                       [-0.3695,  0.3627, -0.0166,  0.3855],
#                       [ 0.0336,  0.3150,  0.0271,  0.4365],
#                       [-0.4465,  0.4115,  0.1667, -0.1465],
#                       [ 0.0711, -0.1607, -0.1763,  0.3508],
#                       [ 0.4016, -0.3105,  0.0110, -0.3478],
#                       [ 0.0676, -0.0706,  0.2178,  0.0236],
#                       [-0.2660, -0.2178,  0.2893,  0.0873],
#                       [-0.1753,  0.3489, -0.2460,  0.1806],
#                       [ 0.3467,  0.1622, -0.3498,  0.1204],
#                       [-0.4957, -0.1383,  0.0655,  0.0051],
#                       [-0.0009,  0.5008,  0.0986, -0.2562],
#                       [ 0.0545, -0.4384, -0.3493, -0.2426],
#                       [-0.3589, -0.3894,  0.1978, -0.4821],
#                       [-0.0449, -0.3548,  0.1262,  0.3578]], device='cuda:0')),
#              ('encoder.0.bias',
#               tensor([-0.4163, -0.3761,  0.0797,  0.2792,  0.2268,  0.1057, -0.3552, -0.3221,
#                       -0.3228, -0.0716,  0.3918,  0.1576, -0.0989,  0.3273,  0.0922, -0.3352,
#                       -0.1592, -0.1625, -0.2745,  0.3531,  0.3015,  0.3609,  0.4217, -0.4686,
#                       -0.4800,  0.3429,  0.1857, -0.4255,  0.4958,  0.2128, -0.0765, -0.3957,
#                        0.3405, -0.3099, -0.3668, -0.0881, -0.4821, -0.0291, -0.4258,  0.1649,
#                        0.4461,  0.3762,  0.2302,  0.2699, -0.0089, -0.3210,  0.3695,  0.0954,
#                        0.5107,  0.1697,  0.1589,  0.2556,  0.2511, -0.4763,  0.0464,  0.4233,
#                       -0.0579, -0.3835,  0.3092,  0.2309,  0.0706, -0.1117, -0.1661,  0.0150,
#                        0.4858,  0.1450,  0.1995, -0.0443, -0.2867,  0.4299, -0.0235, -0.2420,
#                        0.4333,  0.4711,  0.3319,  0.3962, -0.3944, -0.2955, -0.3615, -0.3719,
#                        0.1858, -0.4235, -0.0500, -0.0856, -0.3371,  0.0840, -0.3137, -0.2500],
#                      device='cuda:0')),
#              ('encoder.2.weight',
#               tensor([[ 0.0987,  0.0604,  0.0914,  ..., -0.0906,  0.0237,  0.0758],
#                       [-0.0831, -0.0939,  0.0509,  ..., -0.0795,  0.0990,  0.0936],
#                       [-0.0288,  0.0025, -0.0271,  ...,  0.0687, -0.0057, -0.0235],
#                       ...,
#                       [ 0.0161,  0.0492,  0.0154,  ...,  0.0303,  0.0005,  0.0642],
#                       [ 0.0168,  0.0268, -0.0631,  ..., -0.0394, -0.0501, -0.0028],
#                       [ 0.0369, -0.0167, -0.1076,  ..., -0.0392,  0.0065, -0.0734]],
#                      device='cuda:0')),
#              ('encoder.2.bias',
#               tensor([ 0.0446,  0.0266,  0.0825,  0.1039,  0.0752,  0.0999,  0.0993,  0.0389,
#                        0.0167, -0.0549, -0.0946,  0.0556, -0.0975, -0.0849,  0.1002, -0.0865,
#                        -0.1262,  0.1197, -0.2017,  0.1520, -0.2042,  0.1518, -0.1685, -0.1257,
#                        -0.0286,  0.1318, -0.0633,  0.1815,  0.1974,  0.1751,  0.1474,  0.0560,
#                        -0.1635, -0.0799, -0.1900,  0.0870,  0.1282,  0.1772,  0.1141, -0.0460,
#                         0.0887, -0.0191,  0.0162, -0.1338,  0.1164,  0.1491, -0.2022,  0.1299,
#                        -0.0755,  0.2128, -0.2116, -0.1148, -0.1530,  0.0868, -0.2114, -0.0917,
#                         0.1161,  0.1517,  0.0226,  0.1112,  0.1922,  0.1924,  0.1732, -0.1607,
#                         0.1704, -0.1326,  0.0796, -0.0262,  0.0157, -0.1874,  0.0835, -0.0281,
#                        -0.1669,  0.0945, -0.0840,  0.2025, -0.1945,  0.0999, -0.1953,  0.1139,
#                        -0.0484,  0.0448, -0.1298,  0.0807,  0.2001,  0.0125,  0.0677,  0.0208,
#                        -0.1340, -0.1889]], device='cuda:0')),
#              ('decoder.2.bias',
#               tensor([0.0204, 0.0201, 0.0516, 0.0637], device='cuda:0'))])

# %%
plt.plot(hist)
plt.title("x = self.decoder(x.mean(0))")
plt.show()
minLoss, np.mean(hist[-epoch//4:])
# Out:
# (6.908952236175537, 16.528309461275736)

# %%
plt.plot(hist)
plt.title("return x.mean(0)")
plt.show()
minLoss, np.mean(hist[-epoch//4:])
# Out:
# (0.39412689208984375, 1.2767476003368696)

# %%
seqlen
# Out:
# 40

# %%
net.eval().to("cpu")
# net.msk = net.msk.to("cpu")

src, tgt = next(iter(dataset(60, 60, sqlData, (var, seqlen, 0.2))))
src = torch.from_numpy(src).to(torch.float32).permute(2, 0, 1)
tgt = torch.from_numpy(tgt).to(torch.float32)

with torch.no_grad():
     outputs = net(src)

plt.plot(outputs)
plt.title("outputs")
plt.show()
plt.plot(tgt)
plt.title("target")
plt.show()

plt.plot(tgt-outputs)
plt.title("error")
plt.show()

# %%
for i in range(var):
    plt.plot(outputs[:, i])
    plt.plot(tgt[:, i])
    plt.show()

# %%
src[:, 0, 2]
# Out:
# tensor([2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#         2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#         2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#         2.])

# %%
# Out:
# torch.Size([14, 60, 4])

# %%
for i in range(outputs.shape[1]):
    plt.plot(outputs[i, :], label=["linspace", "rand", *["sin"+str(i+1) for i in range(var-2)]])
    plt.legend()
    plt.show()
    plt.plot(src[:, i, :])
    plt.show()
    print("//////////////////////////////////////////////////////////////////////////////////////////")
# Out:
# //////////////////////////////////////////////////////////////////////////////////////////
# //////////////////////////////////////////////////////////////////////////////////////////
# //////////////////////////////////////////////////////////////////////////////////////////
# //////////////////////////////////////////////////////////////////////////////////////////

# %%
net.mem.sum(0).shape
# Out:
# torch.Size([60, 512])

# %% [markdown]
# # DUEL NET

# %%
plt.plot(net.mem.mean(0).to("cpu")[0, :])
# plt.plot(net.s.to("cpu")[:, 0, :], label="state")
# plt.legend()
plt.show()

# %%
src, tgt = next(iter(dataset(60, seq, 60, sqlData, (var, 50, 0.2))))
print(src.shape)
# Out:
# (60, 4, 17)
